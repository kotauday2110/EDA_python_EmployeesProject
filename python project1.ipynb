# %% [markdown]
# #

# %%
import pandas as pd

# %%
df = pd.read_csv('Salaries.csv', low_memory=False)

# %%
df.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay OvertimePay   OtherPay Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.0  400184.25      NaN  567595.43         567595.43
# 1  155966.02   245131.88  137811.38      NaN  538909.28         538909.28
# 2  212739.13   106088.18    16452.6      NaN  335279.91         335279.91
# 3    77916.0    56120.71   198306.9      NaN  332343.61         332343.61
# 4   134401.6      9737.0  182234.59      NaN  326373.19         326373.19
#
#    Year  Notes         Agency Status
# 0  2011    NaN  San Francisco    NaN
# ...

# %% [markdown]
# Q1.print top 10 and bottom 10 rows

# %%
df.head(10)
# Out:
#    Id        EmployeeName                                        JobTitle  \
# 0   1      NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2        GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3      ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4   CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5     PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# 5   6      DAVID SULLIVAN                       ASSISTANT DEPUTY CHIEF II
# 6   7           ALSON LEE              BATTALION CHIEF, (FIRE DEPARTMENT)
# 7   8       DAVID KUSHNER                  DEPUTY DIRECTOR OF INVESTMENTS
# 8   9      MICHAEL MORRIS              BATTALION CHIEF, (FIRE DEPARTMENT)
# 9  10  JOANNE HAYES-WHITE          CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)
#
#      BasePay OvertimePay   OtherPay Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.0  400184.25      NaN  567595.43         567595.43
# ...

# %%
df.tail(10)
# Out:
#             Id      EmployeeName                      JobTitle       BasePay  \
# 148644  148645      Randy D Winn  Stationary Eng, Sewage Plant          0.00
# 148645  148646  Carolyn A Wilson     Human Services Technician          0.00
# 148646  148647      Not provided                  Not provided  Not Provided
# 148647  148648    Joann Anderson   Communications Dispatcher 2          0.00
# 148648  148649       Leon Walker                     Custodian          0.00
# 148649  148650     Roy I Tillery                     Custodian          0.00
# 148650  148651      Not provided                  Not provided  Not Provided
# 148651  148652      Not provided                  Not provided  Not Provided
# 148652  148653      Not provided                  Not provided  Not Provided
# 148653  148654         Joe Lopez    Counselor, Log Cabin Ranch          0.00
#
#          OvertimePay      OtherPay      Benefits  TotalPay  TotalPayBenefits  \
# ...

# %% [markdown]
# Q2.find number of rows and columns

# %%
df.shape
# Out:
# (148654, 13)

# %%
df.columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency',
#        'Status'],
#       dtype='object')

# %%
print('number of rows:',df.shape[0])
print('number of columns:', df.shape[1])
# Out:
# number of rows: 148654
# number of columns: 13

# %% [markdown]
# find total number of rows, columns and datatypes of columns and memory requirements

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148049 non-null  object
#  4   OvertimePay       148654 non-null  object
#  5   OtherPay          148654 non-null  object
#  6   Benefits          112495 non-null  object
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            38119 non-null   object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 14.7+ MB

# %% [markdown]
# check null values in your data set

# %%
df.isnull()
# Out:
#            Id  EmployeeName  JobTitle  BasePay  OvertimePay  OtherPay  \
# 0       False         False     False    False        False     False
# 1       False         False     False    False        False     False
# 2       False         False     False    False        False     False
# 3       False         False     False    False        False     False
# 4       False         False     False    False        False     False
# ...       ...           ...       ...      ...          ...       ...
# 148649  False         False     False    False        False     False
# 148650  False         False     False    False        False     False
# 148651  False         False     False    False        False     False
# 148652  False         False     False    False        False     False
# 148653  False         False     False    False        False     False
#
#         Benefits  TotalPay  TotalPayBenefits   Year  Notes  Agency  Status
# ...

# %%
df.isnull().sum()
# Out:
# Id                       0
# EmployeeName             0
# JobTitle                 0
# BasePay                605
# OvertimePay              0
# OtherPay                 0
# Benefits             36159
# TotalPay                 0
# TotalPayBenefits         0
# Year                     0
# Notes               148654
# Agency                   0
# Status              110535
# dtype: int64

# %% [markdown]
# DROP ID, NOTES, AGENCY AND STATUS COLUMN

# %%
df.drop(['Id','Notes','Agency', 'Status'], axis='columns')
# Out:
#              EmployeeName                                        JobTitle  \
# 0          NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1            GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2          ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3       CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4         PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# ...                   ...                                             ...
# 148649      Roy I Tillery                                       Custodian
# 148650       Not provided                                    Not provided
# 148651       Not provided                                    Not provided
# 148652       Not provided                                    Not provided
# 148653          Joe Lopez                      Counselor, Log Cabin Ranch
#
#              BasePay   OvertimePay      OtherPay      Benefits   TotalPay  \
# ...

# %% [markdown]
# GET OVERALL STATISTICS OF THE DATA SET

# %%
df.describe()
# Out:
#                   Id       TotalPay  TotalPayBenefits           Year  Notes
# count  148654.000000  148654.000000     148654.000000  148654.000000    0.0
# mean    74327.500000   74768.321972      93692.554811    2012.522643    NaN
# std     42912.857795   50517.005274      62793.533483       1.117538    NaN
# min         1.000000    -618.130000       -618.130000    2011.000000    NaN
# 25%     37164.250000   36168.995000      44065.650000    2012.000000    NaN
# 50%     74327.500000   71426.610000      92404.090000    2013.000000    NaN
# 75%    111490.750000  105839.135000     132876.450000    2014.000000    NaN
# max    148654.000000  567595.430000     567595.430000    2014.000000    NaN

# %%
df.describe(include='all')
# Out:
#                    Id EmployeeName          JobTitle BasePay OvertimePay  \
# count   148654.000000       148654            148654  148049      148654
# unique            NaN       110811              2159  109724       66162
# top               NaN    Kevin Lee  Transit Operator     0.0         0.0
# freq              NaN           13              7036     872       57868
# mean     74327.500000          NaN               NaN     NaN         NaN
# std      42912.857795          NaN               NaN     NaN         NaN
# min          1.000000          NaN               NaN     NaN         NaN
# 25%      37164.250000          NaN               NaN     NaN         NaN
# 50%      74327.500000          NaN               NaN     NaN         NaN
# 75%     111490.750000          NaN               NaN     NaN         NaN
# max     148654.000000          NaN               NaN     NaN         NaN
#
#        OtherPay Benefits       TotalPay  TotalPayBenefits           Year  \
# ...

# %% [markdown]
# find the occurances of top 5  employee names

# %% [markdown]
# df.columns

# %%
df['EmployeeName'].value_counts()
# Out:
# EmployeeName
# Kevin Lee                   13
# Richard Lee                 11
# Steven Lee                  11
# William Wong                11
# Stanley Lee                  9
#                             ..
# Jeffrey Skover               1
# Ken Dever                    1
# Kevin Whitfield              1
# Granville McCollough III     1
# Joe Lopez                    1
# Name: count, Length: 110811, dtype: int64

# %%
df['EmployeeName'].value_counts().head()
# Out:
# EmployeeName
# Kevin Lee       13
# Richard Lee     11
# Steven Lee      11
# William Wong    11
# Stanley Lee      9
# Name: count, dtype: int64

# %% [markdown]
# find the number of unique jobs

# %%
df.columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency',
#        'Status'],
#       dtype='object')

# %%
df['JobTitle'].unique()
# Out:
# array(['GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY',
#        'CAPTAIN III (POLICE DEPARTMENT)',
#        'WIRE ROPE CABLE MAINTENANCE MECHANIC', ..., 'Conversion',
#        'Cashier 3', 'Not provided'], dtype=object)

# %%
df['JobTitle'].nunique()
# Out:
# 2159

# %% [markdown]
# number of job titles contain captain

# %%
df['JobTitle'].str.contains('captain', case=False)
# Out:
# 0         False
# 1          True
# 2          True
# 3         False
# 4         False
#           ...
# 148649    False
# 148650    False
# 148651    False
# 148652    False
# 148653    False
# Name: JobTitle, Length: 148654, dtype: bool

# %%
df[df['JobTitle'].str.contains('captain', case=False)].head(2)
# Out:
#    Id    EmployeeName                         JobTitle    BasePay OvertimePay  \
# 1   2    GARY JIMENEZ  CAPTAIN III (POLICE DEPARTMENT)  155966.02   245131.88
# 2   3  ALBERT PARDINI  CAPTAIN III (POLICE DEPARTMENT)  212739.13   106088.18
#
#     OtherPay Benefits   TotalPay  TotalPayBenefits  Year  Notes  \
# 1  137811.38      NaN  538909.28         538909.28  2011    NaN
# 2    16452.6      NaN  335279.91         335279.91  2011    NaN
#
#           Agency Status
# 1  San Francisco    NaN
# 2  San Francisco    NaN

# %%
len(df[df['JobTitle'].str.contains('captain', case=False)])
# Out:
# 552

# %%
df[df['JobTitle'].str.contains('captain', case=False)].count()
# Out:
# Id                  552
# EmployeeName        552
# JobTitle            552
# BasePay             551
# OvertimePay         552
# OtherPay            552
# Benefits            411
# TotalPay            552
# TotalPayBenefits    552
# Year                552
# Notes                 0
# Agency              552
# Status              141
# dtype: int64

# %% [markdown]
# DISPLAY ALL EMPLOYEES NAMES FROM FIRE DEPARTMENT

# %%
df.columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency',
#        'Status'],
#       dtype='object')

# %%
df[df['JobTitle'].str.contains('fire', case=False)].EmployeeName
# Out:
# 4            PATRICK GARDNER
# 6                  ALSON LEE
# 8             MICHAEL MORRIS
# 9         JOANNE HAYES-WHITE
# 10             ARTHUR KENNEY
#                  ...
# 145956      Kenneth C Farris
# 147556         Edward A Dunn
# 148021        Kari A Johnson
# 148209          Sheryl K Lee
# 148554       Lawrence F Gatt
# Name: EmployeeName, Length: 5879, dtype: object

# %% [markdown]
# FIND MINIMUM , MAX AND AVERAGE BASE PAY

# %%
 pd.to_numeric(df['BasePay'], errors='coerce')
# Out:
# 0         167411.18
# 1         155966.02
# 2         212739.13
# 3          77916.00
# 4         134401.60
#             ...
# 148649         0.00
# 148650          NaN
# 148651          NaN
# 148652          NaN
# 148653         0.00
# Name: BasePay, Length: 148654, dtype: float64

# %% [markdown]
# replace 'NOT PROVIDED' IN EMPLOYEE NAME TO NAN

# %%
df['EmployeeName']
# Out:
# 0            NATHANIEL FORD
# 1              GARY JIMENEZ
# 2            ALBERT PARDINI
# 3         CHRISTOPHER CHONG
# 4           PATRICK GARDNER
#                 ...
# 148649        Roy I Tillery
# 148650         Not provided
# 148651         Not provided
# 148652         Not provided
# 148653            Joe Lopez
# Name: EmployeeName, Length: 148654, dtype: object

# %%
import numpy as np

# %%
df=df['EmployeeName'].replace('Not provided',np.nan)

# %% [markdown]
# drop rows having more than 5 null values

# %%
df = pd.read_csv('Salaries.csv', low_memory=False)

# %%
df
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY     167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)     155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)     212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC       77916.0
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)      134401.6
# ...                                                ...           ...
# ...

# %%
df.isnull().sum(axis=1)
# Out:
# 0         3
# 1         3
# 2         3
# 3         3
# 4         3
#          ..
# 148649    1
# 148650    2
# 148651    2
# 148652    2
# 148653    1
# Length: 148654, dtype: int64

# %%
df.isnull().sum(axis=1)==5
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 148649    False
# 148650    False
# 148651    False
# 148652    False
# 148653    False
# Length: 148654, dtype: bool

# %%
df[df.isnull().sum(axis=1)==2]
# Out:
#             Id        EmployeeName                      JobTitle  \
# 36159    36160      Gary Altenberg  Lieutenant, Fire Suppression
# 36160    36161        Gregory Suhr               Chief of Police
# 36161    36162          Khoa Trinh   Electronic Maintenance Tech
# 36162    36163  Joanne Hayes-White        Chief, Fire Department
# 36163    36164   Frederick Binkley     EMT/Paramedic/Firefighter
# ...        ...                 ...                           ...
# 110520  110521   Carlos J Hernadez        Public Service Trainee
# 148646  148647        Not provided                  Not provided
# 148650  148651        Not provided                  Not provided
# 148651  148652        Not provided                  Not provided
# 148652  148653        Not provided                  Not provided
#
#              BasePay   OvertimePay      OtherPay      Benefits   TotalPay  \
# 36159      128808.87     220909.48      13126.31      44430.12  362844.66
# ...

# %%
df.drop(index=df[df.isnull().sum(axis=1) == 2].index, inplace=True)

# %%
df
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148645  148646   Carolyn A Wilson
# 148647  148648     Joann Anderson
# 148648  148649        Leon Walker
# 148649  148650      Roy I Tillery
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay OvertimePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18         0.0
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02   245131.88
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13   106088.18
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC    77916.0    56120.71
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)   134401.6      9737.0
# ...                                                ...        ...         ...
# ...

# %% [markdown]
# find the job titile of Albert Pardini

# %%
df['EmployeeName']=='ALBERT PARDINI'
# Out:
# 0         False
# 1         False
# 2          True
# 3         False
# 4         False
#           ...
# 148645    False
# 148647    False
# 148648    False
# 148649    False
# 148653    False
# Name: EmployeeName, Length: 74883, dtype: bool

# %%
df[df['EmployeeName']=='ALBERT PARDINI']
# Out:
#    Id    EmployeeName                         JobTitle    BasePay OvertimePay  \
# 2   3  ALBERT PARDINI  CAPTAIN III (POLICE DEPARTMENT)  212739.13   106088.18
#
#   OtherPay Benefits   TotalPay  TotalPayBenefits  Year  Notes         Agency  \
# 2  16452.6      NaN  335279.91         335279.91  2011    NaN  San Francisco
#
#   Status
# 2    NaN

# %%
df[df['EmployeeName']=='ALBERT PARDINI'].JobTitle
# Out:
# 2    CAPTAIN III (POLICE DEPARTMENT)
# Name: JobTitle, dtype: object

# %%
df.head(2)
# Out:
#    Id    EmployeeName                                        JobTitle  \
# 0   1  NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2    GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
#
#      BasePay OvertimePay   OtherPay Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.0  400184.25      NaN  567595.43         567595.43
# 1  155966.02   245131.88  137811.38      NaN  538909.28         538909.28
#
#    Year  Notes         Agency Status
# 0  2011    NaN  San Francisco    NaN
# 1  2011    NaN  San Francisco    NaN

# %% [markdown]
# HOW MUCH DOES ALBERT PARDINI MAKE IN .

# %%
df[df['EmployeeName']=='ALBERT PARDINI'].TotalPayBenefits
# Out:
# 2    335279.91
# Name: TotalPayBenefits, dtype: float64

# %% [markdown]
# DISPLAY NAME OF THE PERSON HAVING HIGHEST BASEPAY

# %%
df['BasePay'] = pd.to_numeric(df['BasePay'], errors='coerce')

# %%
df['BasePay'].max()
# Out:
# 318835.49

# %%
df['BasePay'].max()==df['BasePay']
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 148645    False
# 148647    False
# 148648    False
# 148649    False
# 148653    False
# Name: BasePay, Length: 74883, dtype: bool

# %%
df[df['BasePay'].max()==df['BasePay']]
# Out:
#             Id EmployeeName           JobTitle    BasePay OvertimePay  \
# 110532  110533   Amy P Hart  Asst Med Examiner  318835.49    10712.95
#
#         OtherPay  Benefits   TotalPay  TotalPayBenefits  Year  Notes  \
# 110532  60563.54  89540.23  390111.98         479652.21  2014    NaN
#
#                Agency Status
# 110532  San Francisco     FT

# %% [markdown]
# FIND AVERAGE BASE PAY FOR ALL EMPLOYEES PER YEAR

# %%
df.groupby('Year')['BasePay'].mean()
# Out:
# Year
# 2011    63595.956517
# 2013             NaN
# 2014    66564.421924
# Name: BasePay, dtype: float64

# %%
df['BasePay'] = pd.to_numeric(df['BasePay'], errors='coerce')

# %%
df.groupby('Year')['BasePay'].mean()
# Out:
# Year
# 2011    63595.956517
# 2013             NaN
# 2014    66564.421924
# Name: BasePay, dtype: float64

# %% [markdown]
# FIND THE AVERAGE OF BASE PAY BASED ON THE JOB TITILE

# %%
df.groupby('JobTitle')['BasePay'].mean()
# Out:
# JobTitle
# ACCOUNT CLERK                                     43300.806506
# ACCOUNTANT                                        46643.172000
# ACCOUNTANT INTERN                                 28732.663958
# ACPO,JuvP, Juv Prob (SFERS)                       62290.780000
# ACUPUNCTURIST                                     66374.400000
#                                                       ...
# X-RAY LABORATORY AIDE                             47664.773077
# X-Ray Laboratory Aide                             45490.340286
# YOUTH COMMISSION ADVISOR, BOARD OF SUPERVISORS    52609.910000
# Youth Comm Advisor                                32417.420000
# ZOO CURATOR                                       43148.000000
# Name: BasePay, Length: 2055, dtype: float64

# %% [markdown]
# find the average base having job title as accountant

# %%
df['JobTitle']=='ACCOUNTANT'
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 148645    False
# 148647    False
# 148648    False
# 148649    False
# 148653    False
# Name: JobTitle, Length: 74883, dtype: bool

# %%
df.groupby(df['JobTitle']=='ACCOUNTANT')['BasePay'].mean()
# Out:
# JobTitle
# False    65120.597999
# True     46643.172000
# Name: BasePay, dtype: float64

# %%
df[df['JobTitle']=='ACCOUNTANT']['BasePay'].mean()
# Out:
# 46643.172

# %% [markdown]
# DISPLAY TOP5 MOST COMMON JOBS

# %%
df['JobTitle'].value_counts()
# Out:
# JobTitle
# Transit Operator                                 2540
# TRANSIT OPERATOR                                 2388
# Special Nurse                                    1485
# SPECIAL NURSE                                    1402
# Registered Nurse                                 1245
#                                                  ...
# Librarian 2 - Asian Arts                            1
# LEGISLATIVE ASSISTANT, CITY ATTORNEY'S OFFICE       1
# Media Training Specialist                           1
# SHELTER OFFICE ASSISTANT SUPERVISOR                 1
# Cashier 3                                           1
# Name: count, Length: 2055, dtype: int64

# %%
df['JobTitle'].value_counts().head()
# Out:
# JobTitle
# Transit Operator    2540
# TRANSIT OPERATOR    2388
# Special Nurse       1485
# SPECIAL NURSE       1402
# Registered Nurse    1245
# Name: count, dtype: int64
